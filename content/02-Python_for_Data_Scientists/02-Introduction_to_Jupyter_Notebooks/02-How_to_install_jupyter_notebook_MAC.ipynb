# %% [markdown]
# # How to Download and Install Anaconda/Jupyter Notebook Using MacOS
#
#
# ## Step1
#
#
# First, you have to check the system requirements here according to your Operating System: <br>
# https://conda.io/docs/user-guide/install/index.html <br>
#
# Scroll down to the **"System Requirements"** and make sure you meet the requirements. Don't worry if you do not have Python installed already. Installing Anaconda automatically installs Python.
# Then go to **"Regular Installation"** section and choose your Operating System (Windows or macOS or Linux). This will redirect you to another webpage. <br>
#
#
# Since I will show you how to install Anaconda using MacOS, please follow this link. <br>
# https://www.anaconda.com/download/#macos <br>
#
# <br>
#
# ##  Step 1
#
# <br>
#
# <img src="../../../images/Picture1.png" style="height:40vh">
#
# <br>
#
#
# <br>
#
# ## Step 2
#
# <br>
#
# <img src="../../../images/Picture2.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 3
#
# <br>
#
# <img src="../../../images/Picture3.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 4
#
# <br>
#
# <img src="../../../images/Picture4.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 5
#
# <br>
#
# <img src="../../../images/Picture5.png" style="height:40vh">
# <br>
#
#
# <br>
#
# ##  Step 6
#
# <br>
#
# <img src="../../../images/Picture6.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 7
#
# <br>
#
# <img src="../../../images/Picture7.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 8
#
# <br>
#
# <img src="../../../images/Picture8.png" style="height:40vh">
# <br>
#
# <br>
#
# ##  Step 9
#
# <br>
#
# <img src="../../../images/Picture9.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 10
#
# <br>
#
# <img src="../../../images/Picture10.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 11
#
# <br>
#
# <img src="../../../images/Picture11.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 12
#
# <br>
#
# <img src="../../../images/Picture12.png" style="height:40vh">
#
# <br>
#
#
# <br>
#
# ##  Step 13
#
# <br>
#
# <img src="../../../images/Picture13.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 14
#
# <br>
#
# <img src="../../../images/Picture14.png" style="height:40vh">
#
# <br>
#
# <br>
#
# ##  Step 15
#
# <br>
#
# <img src="../../../images/Picture15.png" style="height:40vh">
#
# <br>

# %%
# End of Notebook

# %% [markdown]
# ### Solution code
#
# ```python
# # End of Notebook
# ```
