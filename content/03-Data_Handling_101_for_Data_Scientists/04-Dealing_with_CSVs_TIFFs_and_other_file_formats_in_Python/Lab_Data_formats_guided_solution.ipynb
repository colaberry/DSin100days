# %% [markdown]
# # Lab:
#
# ## a) Data Formats
#
# In this lab, you are required to write code to make sense of a json text and convert text to an XML format.
#
# Follow these instructions:
#
# 1. Given a variable with json_input with a json text.
# 2. The JSON text is a document representing elements and values. The values could be string, sub-documents or list.
# 3. Each element with the document must converted to an XML format with names, being the tags and values being the inner text within the XML.
# 5. Output must be saved as xml_output variable and print it.
#
# Reference : The input JSON is part of openweathermaps sample - https://samples.openweathermap.org/data/2.5/weather?id=2172797&appid=b6907d289e10d714a6e88b30761fae22
#
#
# ## b) Image Flip
#
# Perform a vertical flip on a given image. The 'Pythonic' way of programming is to use minimum and most efficient code in order to acheive a certain output. Code a pythonic solution using numpy's flip function. Also, code the same solution without using numpy's flip function. The link to the image is "../../../images/lenna.png".

# %%
import json
input_json = '{"coord":{"lon":145.77,"lat":-16.92},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":300.15,"pressure":1007,"humidity":74,"temp_min":300.15,"temp_max":300.15},"visibility":10000,"wind":{"speed":3.6,"deg":160},"clouds":{"all":40},"dt":1485790200,"sys":{"type":1,"id":8166,"message":0.2064,"country":"AU","sunrise":1485720272,"sunset":1485766550},"id":2172797,"name":"Cairns","cod":200}'

#Write/modify your code below:

output_xml = ''

# %%
import pandas as pd 
iris_location = "../../../data/iris.json"
with open(iris_location) as f: 
     json_iris = json.load(f)

# Get the label for the 4 th row 
label = json_iris[3]['species']

# Get the 3 rd column for the 90th row
value = json_iris[89]['petal_length']


# Convert the json_iris file to a dataframe
iris_df = pd.DataFrame(data=json_iris)
iris_df.head()

# Dataframe to dict 
iris_dict = iris_df.to_dict()

# Read 
pd.read_json(iris_location)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### OpenAddress data transformation
# We are going to read the open data into a pandas dataframe and convert it to json

# %%
data_source = "https://github.com/openaddresses/openaddresses/blob/master/us-data/states.txt"

# %%
pd.read_csv(, delimiter="\t")
# Out:
#     Summary Level  Geographic Component  State FIPS  Place FIPS  County FIPS  \
# 0              40                     0           1         NaN          NaN
# 1              40                     0           2         NaN          NaN
# 2              40                     0           4         NaN          NaN
# 3              40                     0           5         NaN          NaN
# 4              40                     0           6         NaN          NaN
# 5              40                     0           8         NaN          NaN
# 6              40                     0           9         NaN          NaN
# 7              40                     0          10         NaN          NaN
# 8              40                     0          11         NaN          NaN
# 9              40                     0          12         NaN          NaN
# 10             40                     0          13         NaN          NaN
# 11             40                     0          15         NaN          NaN
# 12             40                     0          16         NaN          NaN
# 13             40                     0          17         NaN          NaN
# 14             40                     0          18         NaN          NaN
# 15             40                     0          19         NaN          NaN
# 16             40                     0          20         NaN          NaN
# 17             40                     0          21         NaN          NaN
# 18             40                     0          22         NaN          NaN
# 19             40                     0          23         NaN          NaN
# 20             40                     0          24         NaN          NaN
# 21             40                     0          25         NaN          NaN
# 22             40                     0          26         NaN          NaN
# 23             40                     0          27         NaN          NaN
# 24             40                     0          28         NaN          NaN
# 25             40                     0          29         NaN          NaN
# 26             40                     0          30         NaN          NaN
# 27             40                     0          31         NaN          NaN
# 28             40                     0          32         NaN          NaN
# 29             40                     0          33         NaN          NaN
# 30             40                     0          34         NaN          NaN
# 31             40                     0          35         NaN          NaN
# 32             40                     0          36         NaN          NaN
# 33             40                     0          37         NaN          NaN
# 34             40                     0          38         NaN          NaN
# 35             40                     0          39         NaN          NaN
# 36             40                     0          40         NaN          NaN
# 37             40                     0          41         NaN          NaN
# 38             40                     0          42         NaN          NaN
# 39             40                     0          44         NaN          NaN
# 40             40                     0          45         NaN          NaN
# 41             40                     0          46         NaN          NaN
# 42             40                     0          47         NaN          NaN
# 43             40                     0          48         NaN          NaN
# 44             40                     0          49         NaN          NaN
# 45             40                     0          50         NaN          NaN
# 46             40                     0          51         NaN          NaN
