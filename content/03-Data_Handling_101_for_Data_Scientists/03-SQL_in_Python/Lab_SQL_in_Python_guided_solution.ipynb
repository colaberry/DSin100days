# %% [markdown]
# ## The Movies Database
#
# Given is the diagram of movies database consisting of 3 tables - Movies, Halls and Tickets
#
# * Movie: This table has 4 columns - Movie_id (unique identifier for each Movie specific to language), Movie_name (Name of the movie), Language (Language of the Movie), Rating (Average rating given by viewers)
# * Hall: This table has 3 columns - Hall_id (unique identifer for each Movie Hall), Hall_name (Name of the hall), Seating_capacity (maximum ticketed seats available in the hall)
# * Ticket: This table has 3 columns - Movie_id (unique identifier for each Movie specific to language), Hall_id (unique identifer for each Movie Hall), Tickets_sold (number of tickets sold for the given Movie at the given Hall)
#
# <img src="../../../images/movies_db.PNG" style="width:65vw"> <br>
#
# <b>Tasks:</b>
# 1. Create an empty database named 'moviesdb' using connect method.
# 2. Create empty tables with connected relationships among the three tables as shown in above diagram. Using foreign key constraints and enforce referential integrity.
# 3. Extract the data from the three tables, links of which are provided in the code block. Load them into a dataframe and then into the table.
# 4. Write a query to extract data of which movie ran at over 80% of seating capacity and at which hall this was achieved. The query should extract all combinations of movie and hall with over 80% capacity.

# %%
movies_data_link = "../../../data/movie.csv"
halls_data_link = "../../../data/hall.csv"
tickets_data_link = "../../../data/ticket.csv"

# %%
import sqlite3
import pandas as pd 
import numpy as np 

db_name = "movies.db"

# %%
# GOT TO COMMAND LINE AND CREATE DB 
# SET PRAGMA foreign_keys = ON; in sqlite

# %%
moviesdb = sqlite3.connect(db_name)
moviesdb.execute("PRAGMA foreign_keys = 1")
val = moviesdb.execute("PRAGMA foreign_keys")
print(val.fetchall())
# Out:
# [(1,)]

# %%
# fetch contents of movie_table 

def get_movietable(db):
    query = """SELECT * FROM movie_table"""
    cur = db.execute(query)
    return cur.fetchall()

def get_anytable(db, table_name): 
    query = """SELECT * FROM {}""".format(table_name)
    cur = db.execute(query)
    return cur.fetchall()
    
def check_state(db, table_name): 
    state = "Empty"
    table = get_anytable(db, table_name)
    if table: 
        state = "Full" 
    return state

# %% [markdown]
# ## Creating and adding data to Movie Table

# %%
# Creating movie table
movies_table_column_names  = ['movie_id', 'movie_name', 'langauge', 'rating']
col1, col2, col3, col4  = movies_table_column_names
drop_table_query = 'DROP TABLE IF EXISTS movie_table'
movies_table_query = """CREATE TABLE movie_table ( 
                      {} INTEGER NOT NULL PRIMARY KEY,
                      {} TEXT,
                      {} TEXT, 
                      {} INTEGER)""".format(col1, col2, col3, col4)

# Create a list of column names for the movies table. We will use this later

try:
    moviesdb.execute(drop_table_query)
    moviesdb.execute(movies_table_query)
except Exception as e:
    print(e)

info_var = moviesdb.execute("PRAGMA table_info([movie_table]);")
info_var.fetchall()
# Out:
# [(0, 'movie_id', 'INTEGER', 1, None, 1),
#  (1, 'movie_name', 'TEXT', 0, None, 0),
#  (2, 'langauge', 'TEXT', 0, None, 0),
#  (3, 'rating', 'INTEGER', 0, None, 0)]

# %%
movie_table  = get_movietable(moviesdb)
state_movie_table = check_state(moviesdb, "movie_table")
print("State of movie table is {}".format(state_movie_table))
# Out:
# State of movie table is Empty

# %%
# Adding data to movie table
movies_data = pd.read_csv(movies_data_link)
movies_data.columns = movies_table_column_names


movies_data.to_sql(name='movie_table', con=moviesdb, index=False, if_exists='append')

# Checking if the movie table has any data
state_movie_table = check_state(moviesdb, "movie_table")
print("State of movie table is {}".format(state_movie_table))
# Out:
# State of movie table is Full

# %% [markdown]
# ## Creating and adding data to Hall Table

# %%
# Create a list of column names for the hall table. We will use this later
hall_table_column_names  = ['hall_id', 'hall_name', 'seating_capacity']
col1, col2, col3  = hall_table_column_names
hall_table_name = "hall_table"

# drop table if it exists
drop_table_query = 'DROP TABLE IF EXISTS {}'.format(hall_table_name)
hall_table_query = """CREATE TABLE {} (
                      {} INTEGER PRIMARY KEY,
                      {} TEXT,
                      {} INTEGER
                       )""".format(hall_table_name, col1, col2, col3 )


try:
    moviesdb.execute(drop_table_query)
    moviesdb.execute(hall_table_query)
except Exception as e:
    print(e)

# %%
hall_table  = get_anytable(moviesdb, "hall_table")
state_hall_table = check_state(moviesdb, "hall_table")
print("State of hall table is {}".format(state_hall_table))
# Out:
# State of hall table is Empty

# %%
def df_to_table(csv_path, column_names, table_name, db ):
    df = pd.read_csv(csv_path)
    df.columns = column_names
    df.to_sql(name=table_name, con=db, index=False, if_exists='append')    
    state = check_state(db, table_name)
    return df, state 



hall_df , state_hall_table = df_to_table(halls_data_link, hall_table_column_names, hall_table_name, moviesdb)

print("State of hall table is {}".format(state_hall_table))
# Out:
# State of hall table is Full

# %% [markdown]
# ## Creating and adding data to Ticket Table

# %%
# Create a list of column names for the hall table. We will use this later
ticket_table_column_names  = ['movie_id', 'hall_id', 'tickets_sold']
col1, col2, col3  = ticket_table_column_names
ticket_table_name = "ticket_table"

# drop table if it exists
drop_table_query = 'DROP TABLE IF EXISTS {}'.format(ticket_table_name)
ticket_table_query = """CREATE TABLE {} (
                      {} INTEGER,
                      {} INTEGER,
                      {} INTEGER,
                       FOREIGN KEY ({})
                       REFERENCES movie_table ({}), 
                       FOREIGN KEY ({})
                       REFERENCES hall_table ({}))""".format(ticket_table_name, col1, col2, col3, col1, col1, col2, col2  )

try:
    moviesdb.execute(drop_table_query)
    moviesdb.execute(ticket_table_query)
except Exception as e:
    print(e)

# %%
ticket_df , state_ticket_table = df_to_table(tickets_data_link, ticket_table_column_names, ticket_table_name, moviesdb )

# %%
info_var = moviesdb.execute("""SELECT movie_table.movie_name, hall_table.hall_name, ticket_table.tickets_sold 
                               FROM movie_table, hall_table, ticket_table
                               WHERE tickets_sold >= (SELECT 0.80*MAX(ticket_table.tickets_sold) FROM ticket_table) ORDER BY tickets_sold DESC""")
info_var.fetchall()
# Out:
# [('Kobali', 'Princessville Cinema', 148),
#  ('Kobali', "Wang's Town Cinema", 148),
#  ('Kobali', 'Ardour Movie Hall', 148),
#  ('Kobali', 'VMC Hollowville', 148),
#  ('Kobali', 'VMC Frocksburry', 148),
#  ('Kobali', 'VMC Browns', 148),
#  ('Kobali', 'VMC Quasiland', 148),
#  ('Kobali', 'VMC Goodborough', 148),
#  ('Kobali', 'Showtime Browns', 148),
#  ('Kobali', 'Showtime Nathan Square', 148),
#  ('Kobali', 'Showtime Rivermoore', 148),
#  ('Kobali', "Showtime Shwimm's Market", 148),
#  ('Kobali', 'Cangshin Boxes', 148),
#  ('Kobali', 'Wurchester Cinema', 148),
#  ('Kobali', 'Quagmire Movie Hall', 148),
#  ('Senjiruven', 'Princessville Cinema', 148),
#  ('Senjiruven', "Wang's Town Cinema", 148),
#  ('Senjiruven', 'Ardour Movie Hall', 148),
#  ('Senjiruven', 'VMC Hollowville', 148),
#  ('Senjiruven', 'VMC Frocksburry', 148),
#  ('Senjiruven', 'VMC Browns', 148),
#  ('Senjiruven', 'VMC Quasiland', 148),
#  ('Senjiruven', 'VMC Goodborough', 148),
#  ('Senjiruven', 'Showtime Browns', 148),
#  ('Senjiruven', 'Showtime Nathan Square', 148),
#  ('Senjiruven', 'Showtime Rivermoore', 148),
#  ('Senjiruven', "Showtime Shwimm's Market", 148),
#  ('Senjiruven', 'Cangshin Boxes', 148),
#  ('Senjiruven', 'Wurchester Cinema', 148),
#  ('Senjiruven', 'Quagmire Movie Hall', 148),
#  ('Lakewalker', 'Princessville Cinema', 148),
#  ('Lakewalker', "Wang's Town Cinema", 148),
#  ('Lakewalker', 'Ardour Movie Hall', 148),
#  ('Lakewalker', 'VMC Hollowville', 148),
#  ('Lakewalker', 'VMC Frocksburry', 148),
#  ('Lakewalker', 'VMC Browns', 148),
#  ('Lakewalker', 'VMC Quasiland', 148),
#  ('Lakewalker', 'VMC Goodborough', 148),
#  ('Lakewalker', 'Showtime Browns', 148),
#  ('Lakewalker', 'Showtime Nathan Square', 148),
#  ('Lakewalker', 'Showtime Rivermoore', 148),
#  ('Lakewalker', "Showtime Shwimm's Market", 148),
#  ('Lakewalker', 'Cangshin Boxes', 148),
#  ('Lakewalker', 'Wurchester Cinema', 148),
#  ('Lakewalker', 'Quagmire Movie Hall', 148),
#  ('Kobali', 'Princessville Cinema', 148),
#  ('Kobali', "Wang's Town Cinema", 148),
#  ('Kobali', 'Ardour Movie Hall', 148),
#  ('Kobali', 'VMC Hollowville', 148),
#  ('Kobali', 'VMC Frocksburry', 148),
#  ('Kobali', 'VMC Browns', 148),
#  ('Kobali', 'VMC Quasiland', 148),
#  ('Kobali', 'VMC Goodborough', 148),
#  ('Kobali', 'Showtime Browns', 148),
#  ('Kobali', 'Showtime Nathan Square', 148),
#  ('Kobali', 'Showtime Rivermoore', 148),
#  ('Kobali', "Showtime Shwimm's Market", 148),
#  ('Kobali', 'Cangshin Boxes', 148),
#  ('Kobali', 'Wurchester Cinema', 148),
#  ('Kobali', 'Quagmire Movie Hall', 148),
#  ('La Belle', 'Princessville Cinema', 148),
#  ('La Belle', "Wang's Town Cinema", 148),
#  ('La Belle', 'Ardour Movie Hall', 148),
#  ('La Belle', 'VMC Hollowville', 148),
#  ('La Belle', 'VMC Frocksburry', 148),
#  ('La Belle', 'VMC Browns', 148),
#  ('La Belle', 'VMC Quasiland', 148),
#  ('La Belle', 'VMC Goodborough', 148),
#  ('La Belle', 'Showtime Browns', 148),
#  ('La Belle', 'Showtime Nathan Square', 148),
#  ('La Belle', 'Showtime Rivermoore', 148),
#  ('La Belle', "Showtime Shwimm's Market", 148),
#  ('La Belle', 'Cangshin Boxes', 148),
#  ('La Belle', 'Wurchester Cinema', 148),
#  ('La Belle', 'Quagmire Movie Hall', 148),
#  ('Ramen loving Ronin', 'Princessville Cinema', 148),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 148),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 148),
#  ('Ramen loving Ronin', 'VMC Hollowville', 148),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 148),
#  ('Ramen loving Ronin', 'VMC Browns', 148),
#  ('Ramen loving Ronin', 'VMC Quasiland', 148),
#  ('Ramen loving Ronin', 'VMC Goodborough', 148),
#  ('Ramen loving Ronin', 'Showtime Browns', 148),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 148),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 148),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 148),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 148),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 148),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 148),
#  ('The Unimaginable', 'Princessville Cinema', 148),
#  ('The Unimaginable', "Wang's Town Cinema", 148),
#  ('The Unimaginable', 'Ardour Movie Hall', 148),
#  ('The Unimaginable', 'VMC Hollowville', 148),
#  ('The Unimaginable', 'VMC Frocksburry', 148),
#  ('The Unimaginable', 'VMC Browns', 148),
#  ('The Unimaginable', 'VMC Quasiland', 148),
#  ('The Unimaginable', 'VMC Goodborough', 148),
#  ('The Unimaginable', 'Showtime Browns', 148),
#  ('The Unimaginable', 'Showtime Nathan Square', 148),
#  ('The Unimaginable', 'Showtime Rivermoore', 148),
#  ('The Unimaginable', "Showtime Shwimm's Market", 148),
#  ('The Unimaginable', 'Cangshin Boxes', 148),
#  ('The Unimaginable', 'Wurchester Cinema', 148),
#  ('The Unimaginable', 'Quagmire Movie Hall', 148),
#  ('Kobali', 'Princessville Cinema', 147),
#  ('Kobali', "Wang's Town Cinema", 147),
#  ('Kobali', 'Ardour Movie Hall', 147),
#  ('Kobali', 'VMC Hollowville', 147),
#  ('Kobali', 'VMC Frocksburry', 147),
#  ('Kobali', 'VMC Browns', 147),
#  ('Kobali', 'VMC Quasiland', 147),
#  ('Kobali', 'VMC Goodborough', 147),
#  ('Kobali', 'Showtime Browns', 147),
#  ('Kobali', 'Showtime Nathan Square', 147),
#  ('Kobali', 'Showtime Rivermoore', 147),
#  ('Kobali', "Showtime Shwimm's Market", 147),
#  ('Kobali', 'Cangshin Boxes', 147),
#  ('Kobali', 'Wurchester Cinema', 147),
#  ('Kobali', 'Quagmire Movie Hall', 147),
#  ('Senjiruven', 'Princessville Cinema', 147),
#  ('Senjiruven', "Wang's Town Cinema", 147),
#  ('Senjiruven', 'Ardour Movie Hall', 147),
#  ('Senjiruven', 'VMC Hollowville', 147),
#  ('Senjiruven', 'VMC Frocksburry', 147),
#  ('Senjiruven', 'VMC Browns', 147),
#  ('Senjiruven', 'VMC Quasiland', 147),
#  ('Senjiruven', 'VMC Goodborough', 147),
#  ('Senjiruven', 'Showtime Browns', 147),
#  ('Senjiruven', 'Showtime Nathan Square', 147),
#  ('Senjiruven', 'Showtime Rivermoore', 147),
#  ('Senjiruven', "Showtime Shwimm's Market", 147),
#  ('Senjiruven', 'Cangshin Boxes', 147),
#  ('Senjiruven', 'Wurchester Cinema', 147),
#  ('Senjiruven', 'Quagmire Movie Hall', 147),
#  ('Lakewalker', 'Princessville Cinema', 147),
#  ('Lakewalker', "Wang's Town Cinema", 147),
#  ('Lakewalker', 'Ardour Movie Hall', 147),
#  ('Lakewalker', 'VMC Hollowville', 147),
#  ('Lakewalker', 'VMC Frocksburry', 147),
#  ('Lakewalker', 'VMC Browns', 147),
#  ('Lakewalker', 'VMC Quasiland', 147),
#  ('Lakewalker', 'VMC Goodborough', 147),
#  ('Lakewalker', 'Showtime Browns', 147),
#  ('Lakewalker', 'Showtime Nathan Square', 147),
#  ('Lakewalker', 'Showtime Rivermoore', 147),
#  ('Lakewalker', "Showtime Shwimm's Market", 147),
#  ('Lakewalker', 'Cangshin Boxes', 147),
#  ('Lakewalker', 'Wurchester Cinema', 147),
#  ('Lakewalker', 'Quagmire Movie Hall', 147),
#  ('Kobali', 'Princessville Cinema', 147),
#  ('Kobali', "Wang's Town Cinema", 147),
#  ('Kobali', 'Ardour Movie Hall', 147),
#  ('Kobali', 'VMC Hollowville', 147),
#  ('Kobali', 'VMC Frocksburry', 147),
#  ('Kobali', 'VMC Browns', 147),
#  ('Kobali', 'VMC Quasiland', 147),
#  ('Kobali', 'VMC Goodborough', 147),
#  ('Kobali', 'Showtime Browns', 147),
#  ('Kobali', 'Showtime Nathan Square', 147),
#  ('Kobali', 'Showtime Rivermoore', 147),
#  ('Kobali', "Showtime Shwimm's Market", 147),
#  ('Kobali', 'Cangshin Boxes', 147),
#  ('Kobali', 'Wurchester Cinema', 147),
#  ('Kobali', 'Quagmire Movie Hall', 147),
#  ('La Belle', 'Princessville Cinema', 147),
#  ('La Belle', "Wang's Town Cinema", 147),
#  ('La Belle', 'Ardour Movie Hall', 147),
#  ('La Belle', 'VMC Hollowville', 147),
#  ('La Belle', 'VMC Frocksburry', 147),
#  ('La Belle', 'VMC Browns', 147),
#  ('La Belle', 'VMC Quasiland', 147),
#  ('La Belle', 'VMC Goodborough', 147),
#  ('La Belle', 'Showtime Browns', 147),
#  ('La Belle', 'Showtime Nathan Square', 147),
#  ('La Belle', 'Showtime Rivermoore', 147),
#  ('La Belle', "Showtime Shwimm's Market", 147),
#  ('La Belle', 'Cangshin Boxes', 147),
#  ('La Belle', 'Wurchester Cinema', 147),
#  ('La Belle', 'Quagmire Movie Hall', 147),
#  ('Ramen loving Ronin', 'Princessville Cinema', 147),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 147),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 147),
#  ('Ramen loving Ronin', 'VMC Hollowville', 147),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 147),
#  ('Ramen loving Ronin', 'VMC Browns', 147),
#  ('Ramen loving Ronin', 'VMC Quasiland', 147),
#  ('Ramen loving Ronin', 'VMC Goodborough', 147),
#  ('Ramen loving Ronin', 'Showtime Browns', 147),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 147),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 147),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 147),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 147),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 147),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 147),
#  ('The Unimaginable', 'Princessville Cinema', 147),
#  ('The Unimaginable', "Wang's Town Cinema", 147),
#  ('The Unimaginable', 'Ardour Movie Hall', 147),
#  ('The Unimaginable', 'VMC Hollowville', 147),
#  ('The Unimaginable', 'VMC Frocksburry', 147),
#  ('The Unimaginable', 'VMC Browns', 147),
#  ('The Unimaginable', 'VMC Quasiland', 147),
#  ('The Unimaginable', 'VMC Goodborough', 147),
#  ('The Unimaginable', 'Showtime Browns', 147),
#  ('The Unimaginable', 'Showtime Nathan Square', 147),
#  ('The Unimaginable', 'Showtime Rivermoore', 147),
#  ('The Unimaginable', "Showtime Shwimm's Market", 147),
#  ('The Unimaginable', 'Cangshin Boxes', 147),
#  ('The Unimaginable', 'Wurchester Cinema', 147),
#  ('The Unimaginable', 'Quagmire Movie Hall', 147),
#  ('Kobali', 'Princessville Cinema', 145),
#  ('Kobali', "Wang's Town Cinema", 145),
#  ('Kobali', 'Ardour Movie Hall', 145),
#  ('Kobali', 'VMC Hollowville', 145),
#  ('Kobali', 'VMC Frocksburry', 145),
#  ('Kobali', 'VMC Browns', 145),
#  ('Kobali', 'VMC Quasiland', 145),
#  ('Kobali', 'VMC Goodborough', 145),
#  ('Kobali', 'Showtime Browns', 145),
#  ('Kobali', 'Showtime Nathan Square', 145),
#  ('Kobali', 'Showtime Rivermoore', 145),
#  ('Kobali', "Showtime Shwimm's Market", 145),
#  ('Kobali', 'Cangshin Boxes', 145),
#  ('Kobali', 'Wurchester Cinema', 145),
#  ('Kobali', 'Quagmire Movie Hall', 145),
#  ('Senjiruven', 'Princessville Cinema', 145),
#  ('Senjiruven', "Wang's Town Cinema", 145),
#  ('Senjiruven', 'Ardour Movie Hall', 145),
#  ('Senjiruven', 'VMC Hollowville', 145),
#  ('Senjiruven', 'VMC Frocksburry', 145),
#  ('Senjiruven', 'VMC Browns', 145),
#  ('Senjiruven', 'VMC Quasiland', 145),
#  ('Senjiruven', 'VMC Goodborough', 145),
#  ('Senjiruven', 'Showtime Browns', 145),
#  ('Senjiruven', 'Showtime Nathan Square', 145),
#  ('Senjiruven', 'Showtime Rivermoore', 145),
#  ('Senjiruven', "Showtime Shwimm's Market", 145),
#  ('Senjiruven', 'Cangshin Boxes', 145),
#  ('Senjiruven', 'Wurchester Cinema', 145),
#  ('Senjiruven', 'Quagmire Movie Hall', 145),
#  ('Lakewalker', 'Princessville Cinema', 145),
#  ('Lakewalker', "Wang's Town Cinema", 145),
#  ('Lakewalker', 'Ardour Movie Hall', 145),
#  ('Lakewalker', 'VMC Hollowville', 145),
#  ('Lakewalker', 'VMC Frocksburry', 145),
#  ('Lakewalker', 'VMC Browns', 145),
#  ('Lakewalker', 'VMC Quasiland', 145),
#  ('Lakewalker', 'VMC Goodborough', 145),
#  ('Lakewalker', 'Showtime Browns', 145),
#  ('Lakewalker', 'Showtime Nathan Square', 145),
#  ('Lakewalker', 'Showtime Rivermoore', 145),
#  ('Lakewalker', "Showtime Shwimm's Market", 145),
#  ('Lakewalker', 'Cangshin Boxes', 145),
#  ('Lakewalker', 'Wurchester Cinema', 145),
#  ('Lakewalker', 'Quagmire Movie Hall', 145),
#  ('Kobali', 'Princessville Cinema', 145),
#  ('Kobali', "Wang's Town Cinema", 145),
#  ('Kobali', 'Ardour Movie Hall', 145),
#  ('Kobali', 'VMC Hollowville', 145),
#  ('Kobali', 'VMC Frocksburry', 145),
#  ('Kobali', 'VMC Browns', 145),
#  ('Kobali', 'VMC Quasiland', 145),
#  ('Kobali', 'VMC Goodborough', 145),
#  ('Kobali', 'Showtime Browns', 145),
#  ('Kobali', 'Showtime Nathan Square', 145),
#  ('Kobali', 'Showtime Rivermoore', 145),
#  ('Kobali', "Showtime Shwimm's Market", 145),
#  ('Kobali', 'Cangshin Boxes', 145),
#  ('Kobali', 'Wurchester Cinema', 145),
#  ('Kobali', 'Quagmire Movie Hall', 145),
#  ('La Belle', 'Princessville Cinema', 145),
#  ('La Belle', "Wang's Town Cinema", 145),
#  ('La Belle', 'Ardour Movie Hall', 145),
#  ('La Belle', 'VMC Hollowville', 145),
#  ('La Belle', 'VMC Frocksburry', 145),
#  ('La Belle', 'VMC Browns', 145),
#  ('La Belle', 'VMC Quasiland', 145),
#  ('La Belle', 'VMC Goodborough', 145),
#  ('La Belle', 'Showtime Browns', 145),
#  ('La Belle', 'Showtime Nathan Square', 145),
#  ('La Belle', 'Showtime Rivermoore', 145),
#  ('La Belle', "Showtime Shwimm's Market", 145),
#  ('La Belle', 'Cangshin Boxes', 145),
#  ('La Belle', 'Wurchester Cinema', 145),
#  ('La Belle', 'Quagmire Movie Hall', 145),
#  ('Ramen loving Ronin', 'Princessville Cinema', 145),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 145),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 145),
#  ('Ramen loving Ronin', 'VMC Hollowville', 145),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 145),
#  ('Ramen loving Ronin', 'VMC Browns', 145),
#  ('Ramen loving Ronin', 'VMC Quasiland', 145),
#  ('Ramen loving Ronin', 'VMC Goodborough', 145),
#  ('Ramen loving Ronin', 'Showtime Browns', 145),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 145),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 145),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 145),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 145),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 145),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 145),
#  ('The Unimaginable', 'Princessville Cinema', 145),
#  ('The Unimaginable', "Wang's Town Cinema", 145),
#  ('The Unimaginable', 'Ardour Movie Hall', 145),
#  ('The Unimaginable', 'VMC Hollowville', 145),
#  ('The Unimaginable', 'VMC Frocksburry', 145),
#  ('The Unimaginable', 'VMC Browns', 145),
#  ('The Unimaginable', 'VMC Quasiland', 145),
#  ('The Unimaginable', 'VMC Goodborough', 145),
#  ('The Unimaginable', 'Showtime Browns', 145),
#  ('The Unimaginable', 'Showtime Nathan Square', 145),
#  ('The Unimaginable', 'Showtime Rivermoore', 145),
#  ('The Unimaginable', "Showtime Shwimm's Market", 145),
#  ('The Unimaginable', 'Cangshin Boxes', 145),
#  ('The Unimaginable', 'Wurchester Cinema', 145),
#  ('The Unimaginable', 'Quagmire Movie Hall', 145),
#  ('Kobali', 'Princessville Cinema', 141),
#  ('Kobali', "Wang's Town Cinema", 141),
#  ('Kobali', 'Ardour Movie Hall', 141),
#  ('Kobali', 'VMC Hollowville', 141),
#  ('Kobali', 'VMC Frocksburry', 141),
#  ('Kobali', 'VMC Browns', 141),
#  ('Kobali', 'VMC Quasiland', 141),
#  ('Kobali', 'VMC Goodborough', 141),
#  ('Kobali', 'Showtime Browns', 141),
#  ('Kobali', 'Showtime Nathan Square', 141),
#  ('Kobali', 'Showtime Rivermoore', 141),
#  ('Kobali', "Showtime Shwimm's Market", 141),
#  ('Kobali', 'Cangshin Boxes', 141),
#  ('Kobali', 'Wurchester Cinema', 141),
#  ('Kobali', 'Quagmire Movie Hall', 141),
#  ('Senjiruven', 'Princessville Cinema', 141),
#  ('Senjiruven', "Wang's Town Cinema", 141),
#  ('Senjiruven', 'Ardour Movie Hall', 141),
#  ('Senjiruven', 'VMC Hollowville', 141),
#  ('Senjiruven', 'VMC Frocksburry', 141),
#  ('Senjiruven', 'VMC Browns', 141),
#  ('Senjiruven', 'VMC Quasiland', 141),
#  ('Senjiruven', 'VMC Goodborough', 141),
#  ('Senjiruven', 'Showtime Browns', 141),
#  ('Senjiruven', 'Showtime Nathan Square', 141),
#  ('Senjiruven', 'Showtime Rivermoore', 141),
#  ('Senjiruven', "Showtime Shwimm's Market", 141),
#  ('Senjiruven', 'Cangshin Boxes', 141),
#  ('Senjiruven', 'Wurchester Cinema', 141),
#  ('Senjiruven', 'Quagmire Movie Hall', 141),
#  ('Lakewalker', 'Princessville Cinema', 141),
#  ('Lakewalker', "Wang's Town Cinema", 141),
#  ('Lakewalker', 'Ardour Movie Hall', 141),
#  ('Lakewalker', 'VMC Hollowville', 141),
#  ('Lakewalker', 'VMC Frocksburry', 141),
#  ('Lakewalker', 'VMC Browns', 141),
#  ('Lakewalker', 'VMC Quasiland', 141),
#  ('Lakewalker', 'VMC Goodborough', 141),
#  ('Lakewalker', 'Showtime Browns', 141),
#  ('Lakewalker', 'Showtime Nathan Square', 141),
#  ('Lakewalker', 'Showtime Rivermoore', 141),
#  ('Lakewalker', "Showtime Shwimm's Market", 141),
#  ('Lakewalker', 'Cangshin Boxes', 141),
#  ('Lakewalker', 'Wurchester Cinema', 141),
#  ('Lakewalker', 'Quagmire Movie Hall', 141),
#  ('Kobali', 'Princessville Cinema', 141),
#  ('Kobali', "Wang's Town Cinema", 141),
#  ('Kobali', 'Ardour Movie Hall', 141),
#  ('Kobali', 'VMC Hollowville', 141),
#  ('Kobali', 'VMC Frocksburry', 141),
#  ('Kobali', 'VMC Browns', 141),
#  ('Kobali', 'VMC Quasiland', 141),
#  ('Kobali', 'VMC Goodborough', 141),
#  ('Kobali', 'Showtime Browns', 141),
#  ('Kobali', 'Showtime Nathan Square', 141),
#  ('Kobali', 'Showtime Rivermoore', 141),
#  ('Kobali', "Showtime Shwimm's Market", 141),
#  ('Kobali', 'Cangshin Boxes', 141),
#  ('Kobali', 'Wurchester Cinema', 141),
#  ('Kobali', 'Quagmire Movie Hall', 141),
#  ('La Belle', 'Princessville Cinema', 141),
#  ('La Belle', "Wang's Town Cinema", 141),
#  ('La Belle', 'Ardour Movie Hall', 141),
#  ('La Belle', 'VMC Hollowville', 141),
#  ('La Belle', 'VMC Frocksburry', 141),
#  ('La Belle', 'VMC Browns', 141),
#  ('La Belle', 'VMC Quasiland', 141),
#  ('La Belle', 'VMC Goodborough', 141),
#  ('La Belle', 'Showtime Browns', 141),
#  ('La Belle', 'Showtime Nathan Square', 141),
#  ('La Belle', 'Showtime Rivermoore', 141),
#  ('La Belle', "Showtime Shwimm's Market", 141),
#  ('La Belle', 'Cangshin Boxes', 141),
#  ('La Belle', 'Wurchester Cinema', 141),
#  ('La Belle', 'Quagmire Movie Hall', 141),
#  ('Ramen loving Ronin', 'Princessville Cinema', 141),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 141),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 141),
#  ('Ramen loving Ronin', 'VMC Hollowville', 141),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 141),
#  ('Ramen loving Ronin', 'VMC Browns', 141),
#  ('Ramen loving Ronin', 'VMC Quasiland', 141),
#  ('Ramen loving Ronin', 'VMC Goodborough', 141),
#  ('Ramen loving Ronin', 'Showtime Browns', 141),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 141),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 141),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 141),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 141),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 141),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 141),
#  ('The Unimaginable', 'Princessville Cinema', 141),
#  ('The Unimaginable', "Wang's Town Cinema", 141),
#  ('The Unimaginable', 'Ardour Movie Hall', 141),
#  ('The Unimaginable', 'VMC Hollowville', 141),
#  ('The Unimaginable', 'VMC Frocksburry', 141),
#  ('The Unimaginable', 'VMC Browns', 141),
#  ('The Unimaginable', 'VMC Quasiland', 141),
#  ('The Unimaginable', 'VMC Goodborough', 141),
#  ('The Unimaginable', 'Showtime Browns', 141),
#  ('The Unimaginable', 'Showtime Nathan Square', 141),
#  ('The Unimaginable', 'Showtime Rivermoore', 141),
#  ('The Unimaginable', "Showtime Shwimm's Market", 141),
#  ('The Unimaginable', 'Cangshin Boxes', 141),
#  ('The Unimaginable', 'Wurchester Cinema', 141),
#  ('The Unimaginable', 'Quagmire Movie Hall', 141),
#  ('Kobali', 'Princessville Cinema', 136),
#  ('Kobali', "Wang's Town Cinema", 136),
#  ('Kobali', 'Ardour Movie Hall', 136),
#  ('Kobali', 'VMC Hollowville', 136),
#  ('Kobali', 'VMC Frocksburry', 136),
#  ('Kobali', 'VMC Browns', 136),
#  ('Kobali', 'VMC Quasiland', 136),
#  ('Kobali', 'VMC Goodborough', 136),
#  ('Kobali', 'Showtime Browns', 136),
#  ('Kobali', 'Showtime Nathan Square', 136),
#  ('Kobali', 'Showtime Rivermoore', 136),
#  ('Kobali', "Showtime Shwimm's Market", 136),
#  ('Kobali', 'Cangshin Boxes', 136),
#  ('Kobali', 'Wurchester Cinema', 136),
#  ('Kobali', 'Quagmire Movie Hall', 136),
#  ('Senjiruven', 'Princessville Cinema', 136),
#  ('Senjiruven', "Wang's Town Cinema", 136),
#  ('Senjiruven', 'Ardour Movie Hall', 136),
#  ('Senjiruven', 'VMC Hollowville', 136),
#  ('Senjiruven', 'VMC Frocksburry', 136),
#  ('Senjiruven', 'VMC Browns', 136),
#  ('Senjiruven', 'VMC Quasiland', 136),
#  ('Senjiruven', 'VMC Goodborough', 136),
#  ('Senjiruven', 'Showtime Browns', 136),
#  ('Senjiruven', 'Showtime Nathan Square', 136),
#  ('Senjiruven', 'Showtime Rivermoore', 136),
#  ('Senjiruven', "Showtime Shwimm's Market", 136),
#  ('Senjiruven', 'Cangshin Boxes', 136),
#  ('Senjiruven', 'Wurchester Cinema', 136),
#  ('Senjiruven', 'Quagmire Movie Hall', 136),
#  ('Lakewalker', 'Princessville Cinema', 136),
#  ('Lakewalker', "Wang's Town Cinema", 136),
#  ('Lakewalker', 'Ardour Movie Hall', 136),
#  ('Lakewalker', 'VMC Hollowville', 136),
#  ('Lakewalker', 'VMC Frocksburry', 136),
#  ('Lakewalker', 'VMC Browns', 136),
#  ('Lakewalker', 'VMC Quasiland', 136),
#  ('Lakewalker', 'VMC Goodborough', 136),
#  ('Lakewalker', 'Showtime Browns', 136),
#  ('Lakewalker', 'Showtime Nathan Square', 136),
#  ('Lakewalker', 'Showtime Rivermoore', 136),
#  ('Lakewalker', "Showtime Shwimm's Market", 136),
#  ('Lakewalker', 'Cangshin Boxes', 136),
#  ('Lakewalker', 'Wurchester Cinema', 136),
#  ('Lakewalker', 'Quagmire Movie Hall', 136),
#  ('Kobali', 'Princessville Cinema', 136),
#  ('Kobali', "Wang's Town Cinema", 136),
#  ('Kobali', 'Ardour Movie Hall', 136),
#  ('Kobali', 'VMC Hollowville', 136),
#  ('Kobali', 'VMC Frocksburry', 136),
#  ('Kobali', 'VMC Browns', 136),
#  ('Kobali', 'VMC Quasiland', 136),
#  ('Kobali', 'VMC Goodborough', 136),
#  ('Kobali', 'Showtime Browns', 136),
#  ('Kobali', 'Showtime Nathan Square', 136),
#  ('Kobali', 'Showtime Rivermoore', 136),
#  ('Kobali', "Showtime Shwimm's Market", 136),
#  ('Kobali', 'Cangshin Boxes', 136),
#  ('Kobali', 'Wurchester Cinema', 136),
#  ('Kobali', 'Quagmire Movie Hall', 136),
#  ('La Belle', 'Princessville Cinema', 136),
#  ('La Belle', "Wang's Town Cinema", 136),
#  ('La Belle', 'Ardour Movie Hall', 136),
#  ('La Belle', 'VMC Hollowville', 136),
#  ('La Belle', 'VMC Frocksburry', 136),
#  ('La Belle', 'VMC Browns', 136),
#  ('La Belle', 'VMC Quasiland', 136),
#  ('La Belle', 'VMC Goodborough', 136),
#  ('La Belle', 'Showtime Browns', 136),
#  ('La Belle', 'Showtime Nathan Square', 136),
#  ('La Belle', 'Showtime Rivermoore', 136),
#  ('La Belle', "Showtime Shwimm's Market", 136),
#  ('La Belle', 'Cangshin Boxes', 136),
#  ('La Belle', 'Wurchester Cinema', 136),
#  ('La Belle', 'Quagmire Movie Hall', 136),
#  ('Ramen loving Ronin', 'Princessville Cinema', 136),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 136),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 136),
#  ('Ramen loving Ronin', 'VMC Hollowville', 136),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 136),
#  ('Ramen loving Ronin', 'VMC Browns', 136),
#  ('Ramen loving Ronin', 'VMC Quasiland', 136),
#  ('Ramen loving Ronin', 'VMC Goodborough', 136),
#  ('Ramen loving Ronin', 'Showtime Browns', 136),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 136),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 136),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 136),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 136),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 136),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 136),
#  ('The Unimaginable', 'Princessville Cinema', 136),
#  ('The Unimaginable', "Wang's Town Cinema", 136),
#  ('The Unimaginable', 'Ardour Movie Hall', 136),
#  ('The Unimaginable', 'VMC Hollowville', 136),
#  ('The Unimaginable', 'VMC Frocksburry', 136),
#  ('The Unimaginable', 'VMC Browns', 136),
#  ('The Unimaginable', 'VMC Quasiland', 136),
#  ('The Unimaginable', 'VMC Goodborough', 136),
#  ('The Unimaginable', 'Showtime Browns', 136),
#  ('The Unimaginable', 'Showtime Nathan Square', 136),
#  ('The Unimaginable', 'Showtime Rivermoore', 136),
#  ('The Unimaginable', "Showtime Shwimm's Market", 136),
#  ('The Unimaginable', 'Cangshin Boxes', 136),
#  ('The Unimaginable', 'Wurchester Cinema', 136),
#  ('The Unimaginable', 'Quagmire Movie Hall', 136),
#  ('Kobali', 'Princessville Cinema', 133),
#  ('Kobali', "Wang's Town Cinema", 133),
#  ('Kobali', 'Ardour Movie Hall', 133),
#  ('Kobali', 'VMC Hollowville', 133),
#  ('Kobali', 'VMC Frocksburry', 133),
#  ('Kobali', 'VMC Browns', 133),
#  ('Kobali', 'VMC Quasiland', 133),
#  ('Kobali', 'VMC Goodborough', 133),
#  ('Kobali', 'Showtime Browns', 133),
#  ('Kobali', 'Showtime Nathan Square', 133),
#  ('Kobali', 'Showtime Rivermoore', 133),
#  ('Kobali', "Showtime Shwimm's Market", 133),
#  ('Kobali', 'Cangshin Boxes', 133),
#  ('Kobali', 'Wurchester Cinema', 133),
#  ('Kobali', 'Quagmire Movie Hall', 133),
#  ('Senjiruven', 'Princessville Cinema', 133),
#  ('Senjiruven', "Wang's Town Cinema", 133),
#  ('Senjiruven', 'Ardour Movie Hall', 133),
#  ('Senjiruven', 'VMC Hollowville', 133),
#  ('Senjiruven', 'VMC Frocksburry', 133),
#  ('Senjiruven', 'VMC Browns', 133),
#  ('Senjiruven', 'VMC Quasiland', 133),
#  ('Senjiruven', 'VMC Goodborough', 133),
#  ('Senjiruven', 'Showtime Browns', 133),
#  ('Senjiruven', 'Showtime Nathan Square', 133),
#  ('Senjiruven', 'Showtime Rivermoore', 133),
#  ('Senjiruven', "Showtime Shwimm's Market", 133),
#  ('Senjiruven', 'Cangshin Boxes', 133),
#  ('Senjiruven', 'Wurchester Cinema', 133),
#  ('Senjiruven', 'Quagmire Movie Hall', 133),
#  ('Lakewalker', 'Princessville Cinema', 133),
#  ('Lakewalker', "Wang's Town Cinema", 133),
#  ('Lakewalker', 'Ardour Movie Hall', 133),
#  ('Lakewalker', 'VMC Hollowville', 133),
#  ('Lakewalker', 'VMC Frocksburry', 133),
#  ('Lakewalker', 'VMC Browns', 133),
#  ('Lakewalker', 'VMC Quasiland', 133),
#  ('Lakewalker', 'VMC Goodborough', 133),
#  ('Lakewalker', 'Showtime Browns', 133),
#  ('Lakewalker', 'Showtime Nathan Square', 133),
#  ('Lakewalker', 'Showtime Rivermoore', 133),
#  ('Lakewalker', "Showtime Shwimm's Market", 133),
#  ('Lakewalker', 'Cangshin Boxes', 133),
#  ('Lakewalker', 'Wurchester Cinema', 133),
#  ('Lakewalker', 'Quagmire Movie Hall', 133),
#  ('Kobali', 'Princessville Cinema', 133),
#  ('Kobali', "Wang's Town Cinema", 133),
#  ('Kobali', 'Ardour Movie Hall', 133),
#  ('Kobali', 'VMC Hollowville', 133),
#  ('Kobali', 'VMC Frocksburry', 133),
#  ('Kobali', 'VMC Browns', 133),
#  ('Kobali', 'VMC Quasiland', 133),
#  ('Kobali', 'VMC Goodborough', 133),
#  ('Kobali', 'Showtime Browns', 133),
#  ('Kobali', 'Showtime Nathan Square', 133),
#  ('Kobali', 'Showtime Rivermoore', 133),
#  ('Kobali', "Showtime Shwimm's Market", 133),
#  ('Kobali', 'Cangshin Boxes', 133),
#  ('Kobali', 'Wurchester Cinema', 133),
#  ('Kobali', 'Quagmire Movie Hall', 133),
#  ('La Belle', 'Princessville Cinema', 133),
#  ('La Belle', "Wang's Town Cinema", 133),
#  ('La Belle', 'Ardour Movie Hall', 133),
#  ('La Belle', 'VMC Hollowville', 133),
#  ('La Belle', 'VMC Frocksburry', 133),
#  ('La Belle', 'VMC Browns', 133),
#  ('La Belle', 'VMC Quasiland', 133),
#  ('La Belle', 'VMC Goodborough', 133),
#  ('La Belle', 'Showtime Browns', 133),
#  ('La Belle', 'Showtime Nathan Square', 133),
#  ('La Belle', 'Showtime Rivermoore', 133),
#  ('La Belle', "Showtime Shwimm's Market", 133),
#  ('La Belle', 'Cangshin Boxes', 133),
#  ('La Belle', 'Wurchester Cinema', 133),
#  ('La Belle', 'Quagmire Movie Hall', 133),
#  ('Ramen loving Ronin', 'Princessville Cinema', 133),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 133),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 133),
#  ('Ramen loving Ronin', 'VMC Hollowville', 133),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 133),
#  ('Ramen loving Ronin', 'VMC Browns', 133),
#  ('Ramen loving Ronin', 'VMC Quasiland', 133),
#  ('Ramen loving Ronin', 'VMC Goodborough', 133),
#  ('Ramen loving Ronin', 'Showtime Browns', 133),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 133),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 133),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 133),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 133),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 133),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 133),
#  ('The Unimaginable', 'Princessville Cinema', 133),
#  ('The Unimaginable', "Wang's Town Cinema", 133),
#  ('The Unimaginable', 'Ardour Movie Hall', 133),
#  ('The Unimaginable', 'VMC Hollowville', 133),
#  ('The Unimaginable', 'VMC Frocksburry', 133),
#  ('The Unimaginable', 'VMC Browns', 133),
#  ('The Unimaginable', 'VMC Quasiland', 133),
#  ('The Unimaginable', 'VMC Goodborough', 133),
#  ('The Unimaginable', 'Showtime Browns', 133),
#  ('The Unimaginable', 'Showtime Nathan Square', 133),
#  ('The Unimaginable', 'Showtime Rivermoore', 133),
#  ('The Unimaginable', "Showtime Shwimm's Market", 133),
#  ('The Unimaginable', 'Cangshin Boxes', 133),
#  ('The Unimaginable', 'Wurchester Cinema', 133),
#  ('The Unimaginable', 'Quagmire Movie Hall', 133),
#  ('Kobali', 'Princessville Cinema', 124),
#  ('Kobali', "Wang's Town Cinema", 124),
#  ('Kobali', 'Ardour Movie Hall', 124),
#  ('Kobali', 'VMC Hollowville', 124),
#  ('Kobali', 'VMC Frocksburry', 124),
#  ('Kobali', 'VMC Browns', 124),
#  ('Kobali', 'VMC Quasiland', 124),
#  ('Kobali', 'VMC Goodborough', 124),
#  ('Kobali', 'Showtime Browns', 124),
#  ('Kobali', 'Showtime Nathan Square', 124),
#  ('Kobali', 'Showtime Rivermoore', 124),
#  ('Kobali', "Showtime Shwimm's Market", 124),
#  ('Kobali', 'Cangshin Boxes', 124),
#  ('Kobali', 'Wurchester Cinema', 124),
#  ('Kobali', 'Quagmire Movie Hall', 124),
#  ('Senjiruven', 'Princessville Cinema', 124),
#  ('Senjiruven', "Wang's Town Cinema", 124),
#  ('Senjiruven', 'Ardour Movie Hall', 124),
#  ('Senjiruven', 'VMC Hollowville', 124),
#  ('Senjiruven', 'VMC Frocksburry', 124),
#  ('Senjiruven', 'VMC Browns', 124),
#  ('Senjiruven', 'VMC Quasiland', 124),
#  ('Senjiruven', 'VMC Goodborough', 124),
#  ('Senjiruven', 'Showtime Browns', 124),
#  ('Senjiruven', 'Showtime Nathan Square', 124),
#  ('Senjiruven', 'Showtime Rivermoore', 124),
#  ('Senjiruven', "Showtime Shwimm's Market", 124),
#  ('Senjiruven', 'Cangshin Boxes', 124),
#  ('Senjiruven', 'Wurchester Cinema', 124),
#  ('Senjiruven', 'Quagmire Movie Hall', 124),
#  ('Lakewalker', 'Princessville Cinema', 124),
#  ('Lakewalker', "Wang's Town Cinema", 124),
#  ('Lakewalker', 'Ardour Movie Hall', 124),
#  ('Lakewalker', 'VMC Hollowville', 124),
#  ('Lakewalker', 'VMC Frocksburry', 124),
#  ('Lakewalker', 'VMC Browns', 124),
#  ('Lakewalker', 'VMC Quasiland', 124),
#  ('Lakewalker', 'VMC Goodborough', 124),
#  ('Lakewalker', 'Showtime Browns', 124),
#  ('Lakewalker', 'Showtime Nathan Square', 124),
#  ('Lakewalker', 'Showtime Rivermoore', 124),
#  ('Lakewalker', "Showtime Shwimm's Market", 124),
#  ('Lakewalker', 'Cangshin Boxes', 124),
#  ('Lakewalker', 'Wurchester Cinema', 124),
#  ('Lakewalker', 'Quagmire Movie Hall', 124),
#  ('Kobali', 'Princessville Cinema', 124),
#  ('Kobali', "Wang's Town Cinema", 124),
#  ('Kobali', 'Ardour Movie Hall', 124),
#  ('Kobali', 'VMC Hollowville', 124),
#  ('Kobali', 'VMC Frocksburry', 124),
#  ('Kobali', 'VMC Browns', 124),
#  ('Kobali', 'VMC Quasiland', 124),
#  ('Kobali', 'VMC Goodborough', 124),
#  ('Kobali', 'Showtime Browns', 124),
#  ('Kobali', 'Showtime Nathan Square', 124),
#  ('Kobali', 'Showtime Rivermoore', 124),
#  ('Kobali', "Showtime Shwimm's Market", 124),
#  ('Kobali', 'Cangshin Boxes', 124),
#  ('Kobali', 'Wurchester Cinema', 124),
#  ('Kobali', 'Quagmire Movie Hall', 124),
#  ('La Belle', 'Princessville Cinema', 124),
#  ('La Belle', "Wang's Town Cinema", 124),
#  ('La Belle', 'Ardour Movie Hall', 124),
#  ('La Belle', 'VMC Hollowville', 124),
#  ('La Belle', 'VMC Frocksburry', 124),
#  ('La Belle', 'VMC Browns', 124),
#  ('La Belle', 'VMC Quasiland', 124),
#  ('La Belle', 'VMC Goodborough', 124),
#  ('La Belle', 'Showtime Browns', 124),
#  ('La Belle', 'Showtime Nathan Square', 124),
#  ('La Belle', 'Showtime Rivermoore', 124),
#  ('La Belle', "Showtime Shwimm's Market", 124),
#  ('La Belle', 'Cangshin Boxes', 124),
#  ('La Belle', 'Wurchester Cinema', 124),
#  ('La Belle', 'Quagmire Movie Hall', 124),
#  ('Ramen loving Ronin', 'Princessville Cinema', 124),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 124),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 124),
#  ('Ramen loving Ronin', 'VMC Hollowville', 124),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 124),
#  ('Ramen loving Ronin', 'VMC Browns', 124),
#  ('Ramen loving Ronin', 'VMC Quasiland', 124),
#  ('Ramen loving Ronin', 'VMC Goodborough', 124),
#  ('Ramen loving Ronin', 'Showtime Browns', 124),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 124),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 124),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 124),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 124),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 124),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 124),
#  ('The Unimaginable', 'Princessville Cinema', 124),
#  ('The Unimaginable', "Wang's Town Cinema", 124),
#  ('The Unimaginable', 'Ardour Movie Hall', 124),
#  ('The Unimaginable', 'VMC Hollowville', 124),
#  ('The Unimaginable', 'VMC Frocksburry', 124),
#  ('The Unimaginable', 'VMC Browns', 124),
#  ('The Unimaginable', 'VMC Quasiland', 124),
#  ('The Unimaginable', 'VMC Goodborough', 124),
#  ('The Unimaginable', 'Showtime Browns', 124),
#  ('The Unimaginable', 'Showtime Nathan Square', 124),
#  ('The Unimaginable', 'Showtime Rivermoore', 124),
#  ('The Unimaginable', "Showtime Shwimm's Market", 124),
#  ('The Unimaginable', 'Cangshin Boxes', 124),
#  ('The Unimaginable', 'Wurchester Cinema', 124),
#  ('The Unimaginable', 'Quagmire Movie Hall', 124),
#  ('Kobali', 'Princessville Cinema', 121),
#  ('Kobali', "Wang's Town Cinema", 121),
#  ('Kobali', 'Ardour Movie Hall', 121),
#  ('Kobali', 'VMC Hollowville', 121),
#  ('Kobali', 'VMC Frocksburry', 121),
#  ('Kobali', 'VMC Browns', 121),
#  ('Kobali', 'VMC Quasiland', 121),
#  ('Kobali', 'VMC Goodborough', 121),
#  ('Kobali', 'Showtime Browns', 121),
#  ('Kobali', 'Showtime Nathan Square', 121),
#  ('Kobali', 'Showtime Rivermoore', 121),
#  ('Kobali', "Showtime Shwimm's Market", 121),
#  ('Kobali', 'Cangshin Boxes', 121),
#  ('Kobali', 'Wurchester Cinema', 121),
#  ('Kobali', 'Quagmire Movie Hall', 121),
#  ('Senjiruven', 'Princessville Cinema', 121),
#  ('Senjiruven', "Wang's Town Cinema", 121),
#  ('Senjiruven', 'Ardour Movie Hall', 121),
#  ('Senjiruven', 'VMC Hollowville', 121),
#  ('Senjiruven', 'VMC Frocksburry', 121),
#  ('Senjiruven', 'VMC Browns', 121),
#  ('Senjiruven', 'VMC Quasiland', 121),
#  ('Senjiruven', 'VMC Goodborough', 121),
#  ('Senjiruven', 'Showtime Browns', 121),
#  ('Senjiruven', 'Showtime Nathan Square', 121),
#  ('Senjiruven', 'Showtime Rivermoore', 121),
#  ('Senjiruven', "Showtime Shwimm's Market", 121),
#  ('Senjiruven', 'Cangshin Boxes', 121),
#  ('Senjiruven', 'Wurchester Cinema', 121),
#  ('Senjiruven', 'Quagmire Movie Hall', 121),
#  ('Lakewalker', 'Princessville Cinema', 121),
#  ('Lakewalker', "Wang's Town Cinema", 121),
#  ('Lakewalker', 'Ardour Movie Hall', 121),
#  ('Lakewalker', 'VMC Hollowville', 121),
#  ('Lakewalker', 'VMC Frocksburry', 121),
#  ('Lakewalker', 'VMC Browns', 121),
#  ('Lakewalker', 'VMC Quasiland', 121),
#  ('Lakewalker', 'VMC Goodborough', 121),
#  ('Lakewalker', 'Showtime Browns', 121),
#  ('Lakewalker', 'Showtime Nathan Square', 121),
#  ('Lakewalker', 'Showtime Rivermoore', 121),
#  ('Lakewalker', "Showtime Shwimm's Market", 121),
#  ('Lakewalker', 'Cangshin Boxes', 121),
#  ('Lakewalker', 'Wurchester Cinema', 121),
#  ('Lakewalker', 'Quagmire Movie Hall', 121),
#  ('Kobali', 'Princessville Cinema', 121),
#  ('Kobali', "Wang's Town Cinema", 121),
#  ('Kobali', 'Ardour Movie Hall', 121),
#  ('Kobali', 'VMC Hollowville', 121),
#  ('Kobali', 'VMC Frocksburry', 121),
#  ('Kobali', 'VMC Browns', 121),
#  ('Kobali', 'VMC Quasiland', 121),
#  ('Kobali', 'VMC Goodborough', 121),
#  ('Kobali', 'Showtime Browns', 121),
#  ('Kobali', 'Showtime Nathan Square', 121),
#  ('Kobali', 'Showtime Rivermoore', 121),
#  ('Kobali', "Showtime Shwimm's Market", 121),
#  ('Kobali', 'Cangshin Boxes', 121),
#  ('Kobali', 'Wurchester Cinema', 121),
#  ('Kobali', 'Quagmire Movie Hall', 121),
#  ('La Belle', 'Princessville Cinema', 121),
#  ('La Belle', "Wang's Town Cinema", 121),
#  ('La Belle', 'Ardour Movie Hall', 121),
#  ('La Belle', 'VMC Hollowville', 121),
#  ('La Belle', 'VMC Frocksburry', 121),
#  ('La Belle', 'VMC Browns', 121),
#  ('La Belle', 'VMC Quasiland', 121),
#  ('La Belle', 'VMC Goodborough', 121),
#  ('La Belle', 'Showtime Browns', 121),
#  ('La Belle', 'Showtime Nathan Square', 121),
#  ('La Belle', 'Showtime Rivermoore', 121),
#  ('La Belle', "Showtime Shwimm's Market", 121),
#  ('La Belle', 'Cangshin Boxes', 121),
#  ('La Belle', 'Wurchester Cinema', 121),
#  ('La Belle', 'Quagmire Movie Hall', 121),
#  ('Ramen loving Ronin', 'Princessville Cinema', 121),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 121),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 121),
#  ('Ramen loving Ronin', 'VMC Hollowville', 121),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 121),
#  ('Ramen loving Ronin', 'VMC Browns', 121),
#  ('Ramen loving Ronin', 'VMC Quasiland', 121),
#  ('Ramen loving Ronin', 'VMC Goodborough', 121),
#  ('Ramen loving Ronin', 'Showtime Browns', 121),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 121),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 121),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 121),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 121),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 121),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 121),
#  ('The Unimaginable', 'Princessville Cinema', 121),
#  ('The Unimaginable', "Wang's Town Cinema", 121),
#  ('The Unimaginable', 'Ardour Movie Hall', 121),
#  ('The Unimaginable', 'VMC Hollowville', 121),
#  ('The Unimaginable', 'VMC Frocksburry', 121),
#  ('The Unimaginable', 'VMC Browns', 121),
#  ('The Unimaginable', 'VMC Quasiland', 121),
#  ('The Unimaginable', 'VMC Goodborough', 121),
#  ('The Unimaginable', 'Showtime Browns', 121),
#  ('The Unimaginable', 'Showtime Nathan Square', 121),
#  ('The Unimaginable', 'Showtime Rivermoore', 121),
#  ('The Unimaginable', "Showtime Shwimm's Market", 121),
#  ('The Unimaginable', 'Cangshin Boxes', 121),
#  ('The Unimaginable', 'Wurchester Cinema', 121),
#  ('The Unimaginable', 'Quagmire Movie Hall', 121),
#  ('Kobali', 'Princessville Cinema', 120),
#  ('Kobali', "Wang's Town Cinema", 120),
#  ('Kobali', 'Ardour Movie Hall', 120),
#  ('Kobali', 'VMC Hollowville', 120),
#  ('Kobali', 'VMC Frocksburry', 120),
#  ('Kobali', 'VMC Browns', 120),
#  ('Kobali', 'VMC Quasiland', 120),
#  ('Kobali', 'VMC Goodborough', 120),
#  ('Kobali', 'Showtime Browns', 120),
#  ('Kobali', 'Showtime Nathan Square', 120),
#  ('Kobali', 'Showtime Rivermoore', 120),
#  ('Kobali', "Showtime Shwimm's Market", 120),
#  ('Kobali', 'Cangshin Boxes', 120),
#  ('Kobali', 'Wurchester Cinema', 120),
#  ('Kobali', 'Quagmire Movie Hall', 120),
#  ('Senjiruven', 'Princessville Cinema', 120),
#  ('Senjiruven', "Wang's Town Cinema", 120),
#  ('Senjiruven', 'Ardour Movie Hall', 120),
#  ('Senjiruven', 'VMC Hollowville', 120),
#  ('Senjiruven', 'VMC Frocksburry', 120),
#  ('Senjiruven', 'VMC Browns', 120),
#  ('Senjiruven', 'VMC Quasiland', 120),
#  ('Senjiruven', 'VMC Goodborough', 120),
#  ('Senjiruven', 'Showtime Browns', 120),
#  ('Senjiruven', 'Showtime Nathan Square', 120),
#  ('Senjiruven', 'Showtime Rivermoore', 120),
#  ('Senjiruven', "Showtime Shwimm's Market", 120),
#  ('Senjiruven', 'Cangshin Boxes', 120),
#  ('Senjiruven', 'Wurchester Cinema', 120),
#  ('Senjiruven', 'Quagmire Movie Hall', 120),
#  ('Lakewalker', 'Princessville Cinema', 120),
#  ('Lakewalker', "Wang's Town Cinema", 120),
#  ('Lakewalker', 'Ardour Movie Hall', 120),
#  ('Lakewalker', 'VMC Hollowville', 120),
#  ('Lakewalker', 'VMC Frocksburry', 120),
#  ('Lakewalker', 'VMC Browns', 120),
#  ('Lakewalker', 'VMC Quasiland', 120),
#  ('Lakewalker', 'VMC Goodborough', 120),
#  ('Lakewalker', 'Showtime Browns', 120),
#  ('Lakewalker', 'Showtime Nathan Square', 120),
#  ('Lakewalker', 'Showtime Rivermoore', 120),
#  ('Lakewalker', "Showtime Shwimm's Market", 120),
#  ('Lakewalker', 'Cangshin Boxes', 120),
#  ('Lakewalker', 'Wurchester Cinema', 120),
#  ('Lakewalker', 'Quagmire Movie Hall', 120),
#  ('Kobali', 'Princessville Cinema', 120),
#  ('Kobali', "Wang's Town Cinema", 120),
#  ('Kobali', 'Ardour Movie Hall', 120),
#  ('Kobali', 'VMC Hollowville', 120),
#  ('Kobali', 'VMC Frocksburry', 120),
#  ('Kobali', 'VMC Browns', 120),
#  ('Kobali', 'VMC Quasiland', 120),
#  ('Kobali', 'VMC Goodborough', 120),
#  ('Kobali', 'Showtime Browns', 120),
#  ('Kobali', 'Showtime Nathan Square', 120),
#  ('Kobali', 'Showtime Rivermoore', 120),
#  ('Kobali', "Showtime Shwimm's Market", 120),
#  ('Kobali', 'Cangshin Boxes', 120),
#  ('Kobali', 'Wurchester Cinema', 120),
#  ('Kobali', 'Quagmire Movie Hall', 120),
#  ('La Belle', 'Princessville Cinema', 120),
#  ('La Belle', "Wang's Town Cinema", 120),
#  ('La Belle', 'Ardour Movie Hall', 120),
#  ('La Belle', 'VMC Hollowville', 120),
#  ('La Belle', 'VMC Frocksburry', 120),
#  ('La Belle', 'VMC Browns', 120),
#  ('La Belle', 'VMC Quasiland', 120),
#  ('La Belle', 'VMC Goodborough', 120),
#  ('La Belle', 'Showtime Browns', 120),
#  ('La Belle', 'Showtime Nathan Square', 120),
#  ('La Belle', 'Showtime Rivermoore', 120),
#  ('La Belle', "Showtime Shwimm's Market", 120),
#  ('La Belle', 'Cangshin Boxes', 120),
#  ('La Belle', 'Wurchester Cinema', 120),
#  ('La Belle', 'Quagmire Movie Hall', 120),
#  ('Ramen loving Ronin', 'Princessville Cinema', 120),
#  ('Ramen loving Ronin', "Wang's Town Cinema", 120),
#  ('Ramen loving Ronin', 'Ardour Movie Hall', 120),
#  ('Ramen loving Ronin', 'VMC Hollowville', 120),
#  ('Ramen loving Ronin', 'VMC Frocksburry', 120),
#  ('Ramen loving Ronin', 'VMC Browns', 120),
#  ('Ramen loving Ronin', 'VMC Quasiland', 120),
#  ('Ramen loving Ronin', 'VMC Goodborough', 120),
#  ('Ramen loving Ronin', 'Showtime Browns', 120),
#  ('Ramen loving Ronin', 'Showtime Nathan Square', 120),
#  ('Ramen loving Ronin', 'Showtime Rivermoore', 120),
#  ('Ramen loving Ronin', "Showtime Shwimm's Market", 120),
#  ('Ramen loving Ronin', 'Cangshin Boxes', 120),
#  ('Ramen loving Ronin', 'Wurchester Cinema', 120),
#  ('Ramen loving Ronin', 'Quagmire Movie Hall', 120),
#  ('The Unimaginable', 'Princessville Cinema', 120),
#  ('The Unimaginable', "Wang's Town Cinema", 120),
#  ('The Unimaginable', 'Ardour Movie Hall', 120),
#  ('The Unimaginable', 'VMC Hollowville', 120),
#  ('The Unimaginable', 'VMC Frocksburry', 120),
#  ('The Unimaginable', 'VMC Browns', 120),
#  ('The Unimaginable', 'VMC Quasiland', 120),
#  ('The Unimaginable', 'VMC Goodborough', 120),
#  ('The Unimaginable', 'Showtime Browns', 120),
#  ('The Unimaginable', 'Showtime Nathan Square', 120),
#  ('The Unimaginable', 'Showtime Rivermoore', 120),
#  ('The Unimaginable', "Showtime Shwimm's Market", 120),
#  ('The Unimaginable', 'Cangshin Boxes', 120),
#  ('The Unimaginable', 'Wurchester Cinema', 120),
#  ('The Unimaginable', 'Quagmire Movie Hall', 120),
#  ('Kobali', 'Princessville Cinema', 119),
#  ('Kobali', "Wang's Town Cinema", 119),
#  ('Kobali', 'Ardour Movie Hall', 119),
#  ('Kobali', 'VMC Hollowville', 119),
#  ('Kobali', 'VMC Frocksburry', 119),
#  ('Kobali', 'VMC Browns', 119),
#  ('Kobali', 'VMC Quasiland', 119),
#  ('Kobali', 'VMC Goodborough', 119),
#  ('Kobali', 'Showtime Browns', 119),
#  ('Kobali', 'Showtime Nathan Square', 119),
#  ('Kobali', 'Showtime Rivermoore', 119),
#  ('Kobali', "Showtime Shwimm's Market", 119),
#  ('Kobali', 'Cangshin Boxes', 119),
#  ('Kobali', 'Wurchester Cinema', 119),
#  ('Kobali', 'Quagmire Movie Hall', 119),
#  ('Senjiruven', 'Princessville Cinema', 119),
#  ('Senjiruven', "Wang's Town Cinema", 119),
#  ('Senjiruven', 'Ardour Movie Hall', 119),
#  ('Senjiruven', 'VMC Hollowville', 119),
#  ('Senjiruven', 'VMC Frocksburry', 119),
#  ('Senjiruven', 'VMC Browns', 119),
#  ('Senjiruven', 'VMC Quasiland', 119),
#  ('Senjiruven', 'VMC Goodborough', 119),
#  ('Senjiruven', 'Showtime Browns', 119),
#  ('Senjiruven', 'Showtime Nathan Square', 119),
#  ('Senjiruven', 'Showtime Rivermoore', 119),
#  ('Senjiruven', "Showtime Shwimm's Market", 119),
#  ('Senjiruven', 'Cangshin Boxes', 119),
#  ('Senjiruven', 'Wurchester Cinema', 119),
#  ('Senjiruven', 'Quagmire Movie Hall', 119),
#  ('Lakewalker', 'Princessville Cinema', 119),
#  ('Lakewalker', "Wang's Town Cinema", 119),
#  ('Lakewalker', 'Ardour Movie Hall', 119),
#  ('Lakewalker', 'VMC Hollowville', 119),
#  ('Lakewalker', 'VMC Frocksburry', 119),
#  ('Lakewalker', 'VMC Browns', 119),
#  ('Lakewalker', 'VMC Quasiland', 119),
#  ('Lakewalker', 'VMC Goodborough', 119),
#  ('Lakewalker', 'Showtime Browns', 119),
#  ('Lakewalker', 'Showtime Nathan Square', 119),
#  ('Lakewalker', 'Showtime Rivermoore', 119),
#  ('Lakewalker', "Showtime Shwimm's Market", 119),
#  ('Lakewalker', 'Cangshin Boxes', 119),
#  ('Lakewalker', 'Wurchester Cinema', 119),
#  ('Lakewalker', 'Quagmire Movie Hall', 119),
#  ('Kobali', 'Princessville Cinema', 119),
#  ('Kobali', "Wang's Town Cinema", 119),
#  ('Kobali', 'Ardour Movie Hall', 119),
#  ('Kobali', 'VMC Hollowville', 119),
#  ('Kobali', 'VMC Frocksburry', 119),
#  ('Kobali', 'VMC Browns', 119),
#  ('Kobali', 'VMC Quasiland', 119),
#  ('Kobali', 'VMC Goodborough', 119),
#  ('Kobali', 'Showtime Browns', 119),
#  ('Kobali', 'Showtime Nathan Square', 119),
#  ...]
