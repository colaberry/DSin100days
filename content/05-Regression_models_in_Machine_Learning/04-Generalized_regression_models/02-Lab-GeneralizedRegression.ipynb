# %% [markdown]
# ## Lab  - Generalized Linear Regression
#
# In this lab, you need to work with boston housing data and perform Generalized regression using statsmodels library. Your task is to find the most appropriate family of probability distribution applicable for the labels.
# Also find the appropriate link function and create the model. Set the model in the variable "answer".

# %%
from sklearn import datasets
import numpy as np
import pandas as pd

#load boston dataset
boston_dataset = datasets.load_boston()
boston_data = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston_data.head()

#Write your code here or in other code cells down
#Set the Final model in a variable answer
#answer =
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
