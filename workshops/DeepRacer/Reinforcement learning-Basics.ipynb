# %% [markdown]
# # __Reinforcement Learning__

# %% [markdown]
# What is Reinforcement Learning?
#
# Let us being with breaking down the words into simplier definitions

# %% [markdown]
# ### What does Reinforcement mean?
# Reinforcements means the process of encouraging or establishing a belief or pattern of behavior, especially by encouragement or reward.
#
# Let us take an example of training puppies

# %% [markdown]
# <img src="Reinforcement learning images/Fig1.PNG">

# %% [markdown]
# ### Another Example can be of how we solve a maze

# %% [markdown]
# <img src="Reinforcement learning images/Fig2.PNG">

# %% [markdown]
# ### An Insight to this would be:
# In the above example, you are the agent who is trying to complete the maze, which is the environment. Walking is the action the agent performs on the environment. The nearer we are to the maze exit we know we are making the right decisions- this acts as a reward. The agent tries to perform the action in such a way that the reward maximizes. This is how Reinforcement Learning works in a nutshell.

# %% [markdown]
# ### To put this into a simple diagram:

# %% [markdown]
# <img src="Reinforcement learning images/Fig3.PNG">

# %% [markdown]
# In terms of computer science we have this same image as

# %% [markdown]
# <img src="Reinforcement learning images/Fig4.PNG">

# %% [markdown]
# ## Definition of Reinforcement learning
# Reinforcement learning (RL) is an area of machine learning concerned with how software agents ought to take actions in an environment in order to maximize the notion of cumulative reward

# %% [markdown]
# Let us take a look at a real implementation of a reinforcement learning

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('IngelKjmecg')

# %% [markdown]
# To go over the formal definitions of Reinformcement learning parts:
#
# **Agent**: a hypothetical entity which performs actions in an environment to gain some reward.
#
# **Action (a)**: All the possible moves that the agent can take.
#
# **Environment (e)**: A scenario the agent has to face.
#
# **State (s)**: Current situation returned by the environment.
#
# **Reward (R)**: An immediate return sent back from the environment to evaluate the last action by the agent.
#
# **Policy (π)**: The strategy that the agent employs to determine next action based on the current state.
